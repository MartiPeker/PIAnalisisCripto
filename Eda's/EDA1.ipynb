# %% [markdown]
# IMPORTANTE: para utilizar cualquiera de los EDA, hay que poner la API-KEY de Binance de cada uno! (Por obvias cuestiones de seguridad, yo subo los EDA sin las key)

# %%
# !pip install python-binance

from binance.client import Client
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-binance in c:\users\marti\desktop\analisis\venv\lib\site-packages (1.0.19)
# Requirement already satisfied: requests in c:\users\marti\desktop\analisis\venv\lib\site-packages (from python-binance) (2.31.0)
# Requirement already satisfied: six in c:\users\marti\desktop\analisis\venv\lib\site-packages (from python-binance) (1.16.0)
# Requirement already satisfied: dateparser in c:\users\marti\desktop\analisis\venv\lib\site-packages (from python-binance) (1.1.8)
# Requirement already satisfied: aiohttp in c:\users\marti\desktop\analisis\venv\lib\site-packages (from python-binance) (3.8.5)
# Requirement already satisfied: ujson in c:\users\marti\desktop\analisis\venv\lib\site-packages (from python-binance) (5.8.0)
# Requirement already satisfied: websockets in c:\users\marti\desktop\analisis\venv\lib\site-packages (from python-binance) (11.0.3)
# Requirement already satisfied: pycryptodome in c:\users\marti\desktop\analisis\venv\lib\site-packages (from python-binance) (3.18.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\marti\desktop\analisis\venv\lib\site-packages (from aiohttp->python-binance) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\marti\desktop\analisis\venv\lib\site-packages (from aiohttp->python-binance) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\marti\desktop\analisis\venv\lib\site-packages (from aiohttp->python-binance) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\marti\desktop\analisis\venv\lib\site-packages (from aiohttp->python-binance) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\marti\desktop\analisis\venv\lib\site-packages (from aiohttp->python-binance) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\marti\desktop\analisis\venv\lib\site-packages (from aiohttp->python-binance) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\marti\desktop\analisis\venv\lib\site-packages (from aiohttp->python-binance) (1.3.1)
# Requirement already satisfied: python-dateutil in c:\users\marti\desktop\analisis\venv\lib\site-packages (from dateparser->python-binance) (2.8.2)
# Requirement already satisfied: pytz in c:\users\marti\desktop\analisis\venv\lib\site-packages (from dateparser->python-binance) (2023.3)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in c:\users\marti\desktop\analisis\venv\lib\site-packages (from dateparser->python-binance) (2023.8.8)
# Requirement already satisfied: tzlocal in c:\users\marti\desktop\analisis\venv\lib\site-packages (from dateparser->python-binance) (4.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marti\desktop\analisis\venv\lib\site-packages (from requests->python-binance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marti\desktop\analisis\venv\lib\site-packages (from requests->python-binance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marti\desktop\analisis\venv\lib\site-packages (from requests->python-binance) (2023.7.22)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\marti\desktop\analisis\venv\lib\site-packages (from tzlocal->dateparser->python-binance) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\marti\desktop\analisis\venv\lib\site-packages (from tzlocal->dateparser->python-binance) (2023.3)

# %% [markdown]
# Importación de librerías necesarias:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import seaborn as sns

# %% [markdown]
# **Análisis Exploratorio de Datos**

# %% [markdown]
# En base a la documentación de Binance, consumo la api y pruebo si me trae el valor actual de BTC

# %%
api_key = 'completar con api key de binance'
api_secret = 'completar con api secret de binance'

client = Client(api_key, api_secret)

ticker = client.get_ticker(symbol='BTCUSDT')

print(f"precio actual BTC: {ticker['lastPrice']}")
# Out:
# precio actual BTC: 29249.85000000

# %%
#Los datos de las columnas los saque de la documentación
columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']
interval = Client.KLINE_INTERVAL_1DAY #el intervalo de las velas va a ser de 1 día.
klines = client.get_klines(symbol='BTCUSDT', interval=interval)

#Creo un dataframe para explorar btc:
df = pd.DataFrame(klines, columns=columns)
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')

# %%
df.head()
# Out:
#    timestamp            open            high             low           close  \
# 0 2022-04-03  45810.99000000  47444.11000000  45530.92000000  46407.35000000
# 1 2022-04-04  46407.36000000  46890.71000000  45118.00000000  46580.51000000
# 2 2022-04-05  46580.50000000  47200.00000000  45353.81000000  45497.55000000
# 3 2022-04-06  45497.54000000  45507.14000000  43121.00000000  43170.47000000
# 4 2022-04-07  43170.47000000  43900.99000000  42727.35000000  43444.19000000
#
#            volume     close_time   quote_asset_volume  number_of_trades  \
# 0  33394.67794000  1649030399999  1550999693.05080480            966563
# 1  44641.87514000  1649116799999  2053434523.86853890           1171998
# 2  42192.74852000  1649203199999  1951668192.92950980           1046080
# 3  60849.32936000  1649289599999  2700644700.89039180           1471912
# 4  37396.54156000  1649375999999  1623879486.66003130            999816
#
#   taker_buy_base_asset_volume taker_buy_quote_asset_volume ignore
# 0              16740.18067000           777615974.81551770      0
# 1              21913.04154000          1008164276.04901840      0
# 2              20607.57735000           953494654.45992840      0
# 3              29467.28381000          1307725131.19462540      0
# 4              18567.25999000           806358703.21566620      0

# %%
print(df.describe())
# Out:
#                  timestamp    close_time  number_of_trades
# count                  500  5.000000e+02      5.000000e+02
# mean   2022-12-08 12:00:00  1.670587e+12      3.754316e+06
# min    2022-04-03 00:00:00  1.649030e+12      3.108520e+05
# 25%    2022-08-05 18:00:00  1.659809e+12      1.015768e+06
# 50%    2022-12-08 12:00:00  1.670587e+12      3.246832e+06
# 75%    2023-04-12 06:00:00  1.681366e+12      5.837862e+06
# max    2023-08-15 00:00:00  1.692144e+12      1.522359e+07
# std                    NaN  1.248323e+10      3.118662e+06

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   timestamp                     500 non-null    datetime64[ns]
#  1   open                          500 non-null    object
#  2   high                          500 non-null    object
#  3   low                           500 non-null    object
#  4   close                         500 non-null    object
#  5   volume                        500 non-null    object
#  6   close_time                    500 non-null    int64
#  7   quote_asset_volume            500 non-null    object
#  8   number_of_trades              500 non-null    int64
#  9   taker_buy_base_asset_volume   500 non-null    object
#  10  taker_buy_quote_asset_volume  500 non-null    object
#  11  ignore                        500 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 47.0+ KB
# None

# %%
df.isnull().sum() #esto no tiene mucho sentido en este tipo de datos, son registros completos y al ser sacados de la API oficial de binance, 
#algunos de los chequeos que se hacen generalmente en df convencionales quedan obsoletos en este tipo de información donde suele ya haber un trabajo 
#de estructura y selección(para levantar los graficos en BINANCE y los clientes puedan e interactuar con las criptomonedas minuto a minuto)
# Out:
# timestamp                       0
# open                            0
# high                            0
# low                             0
# close                           0
# volume                          0
# close_time                      0
# quote_asset_volume              0
# number_of_trades                0
# taker_buy_base_asset_volume     0
# taker_buy_quote_asset_volume    0
# ignore                          0
# dtype: int64

# %% [markdown]
# Variables que me parecen interesantespero que aun no exporte:
# symbol: el simbolo de la criptomoneda
# price: precio.
# market_cap: la capitalizacion.

# %%
symbol = 'BTCUSDT'
limit = 100  #cantidad de puntos de data

#traigo data de btc del año 2019
candles = client.get_historical_klines(symbol=symbol, interval=Client.KLINE_INTERVAL_1DAY, start_str='2019-01-01', end_str='2019-12-31')
df = pd.DataFrame(candles, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])

#conversion de timestamp en date
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
df.set_index('timestamp', inplace=True)

volume_trace = go.Bar(
    x=df.index,
    y=df['volume'].astype(float),
    marker=dict(color='blue'),
    name='Volumen'
)

candlestick_trace = go.Candlestick(
       x=df.index,
       open=df['open'].astype(float),
       high=df['high'].astype(float),
       low=df['low'].astype(float),
       close=df['close'].astype(float),
       name='Precios'
   )

fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.1, row_heights=[0.7, 0.3])
fig.add_trace(candlestick_trace, row=1, col=1)
fig.add_trace(volume_trace, row=2, col=1)
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()

# %% [markdown]
# Cuando el precio del Bitcoin sube, los traders tienden a ser estar menos activos y el volumen de negociación baja (creeria yo en base a este grafico y analisis extra en internet, que porque no les conviene la venta).
# Pero si el precio baja, los traders ven una oportunidad de venta por ende el volumen aumenta.
# La subida de precios puede significar menos acción, y bajada de precios puede significar mas movimiento en criptos.

# %%
df['close'] = pd.to_numeric(df['close'])
#no podía sacar la correlacion con "close" porque no todos los datos eran de tipo numerico. 
# (subestime un poco al creer que algunos chequeos quedaban "obsoletos en este tipo de información")

# %%
df['volume'] = pd.to_numeric(df['volume'])

# %%
correlation_matrix = df.corr()

#mapa de calor
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.show()

# %% [markdown]
# Estos datos no son ideales para sacar correlación, si bien son datos cuantitativos y en el mapa de calor se ve sectores de maxima correlacion... la "correlación" es porque los datos fluctuan de apoco, siguen un camino lento de una fase a la otra.
# Sucede tanto en la apertura, bajada, subida y cierre como en el volumen, numero de operaciones y traders, pero estos valores de correlación altos no significan que tengamos un patron que nos revele algo interesante entre estas variables.

# %%
symbols = ['BTCUSDT', 'ETHUSDT', 'XRPUSDT', 'MATICUSDT']

interval = Client.KLINE_INTERVAL_1DAY

start_date = 1356998400000

historical_data = {}

for symbol in symbols:
    klines = client.get_historical_klines(symbol, interval, start_str=start_date)
    historical_data[symbol] = klines

#dataframe para cada cripto
dataframes = {}
for symbol, klines in historical_data.items():
    columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']
    df = pd.DataFrame(klines, columns=columns)
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    dataframes[symbol] = df

# %%
filter_df = dataframes['MATICUSDT']
filter_df_year = filter_df[filter_df['timestamp'].dt.year == 2019]  #filtro por año
print(filter_df_year)
# Out:
#      timestamp        open        high         low       close  \
# 0   2019-04-26  0.00990000  0.01052000  0.00481000  0.00545000
# 1   2019-04-27  0.00543000  0.00586000  0.00516000  0.00521000
# 2   2019-04-28  0.00521000  0.00527000  0.00434000  0.00442000
# 3   2019-04-29  0.00442000  0.00456000  0.00343000  0.00347000
# 4   2019-04-30  0.00346000  0.00516000  0.00346000  0.00442000
# ..         ...         ...         ...         ...         ...
# 245 2019-12-27  0.01563000  0.01585000  0.01451000  0.01518000
# 246 2019-12-28  0.01519000  0.01546000  0.01492000  0.01494000
# 247 2019-12-29  0.01494000  0.01539000  0.01455000  0.01474000
# 248 2019-12-30  0.01473000  0.01496000  0.01420000  0.01427000
# 249 2019-12-31  0.01428000  0.01451000  0.01366000  0.01379000
#
#                   volume     close_time quote_asset_volume  number_of_trades  \
# 0    2251813333.70000000  1556323199999  13165943.99965100             29783
# 1     440339020.00000000  1556409599999   2401118.02948200              7591
# 2     457183971.50000000  1556495999999   2218764.98535100              7463
# 3     520557584.60000000  1556582399999   2090178.57133000              7321
# 4    1165706893.80000000  1556668799999   5268819.86829800             14764
# ..                   ...            ...                ...               ...
# 245   348584709.00000000  1577491199999   5283708.14394900             15315
# 246   167633035.00000000  1577577599999   2533570.07861300              7879
# 247   286595877.40000000  1577663999999   4277720.96537600             12136
# 248   182360796.30000000  1577750399999   2656443.79665000              8519
# 249   220977375.50000000  1577836799999   3098512.90414300              8946
#
#     taker_buy_base_asset_volume taker_buy_quote_asset_volume ignore
# 0            992882444.00000000             5829864.14588800      0
# 1            196839741.60000000             1075229.90979500      0
# 2            174578789.20000000              851288.96241000      0
# 3            193985377.50000000              776881.25854200      0
# 4            469118811.20000000             2125649.11569400      0
# ..                          ...                          ...    ...
# 245          156861311.10000000             2376834.10280400      0
# 246           72909038.40000000             1103203.25420600      0
# 247          124740420.90000000             1865480.81434500      0
# 248           82140417.90000000             1196387.31036600      0
# 249          105536134.50000000             1481035.91494100      0
#
# [250 rows x 12 columns]

# %% [markdown]
# Con la siguiente celda, guardo los archivos extraidos en un csv

# %%
#for symbol, df in historical_data.items():
#    df = pd.DataFrame(df)
#    df.to_csv(f'{symbol}_historical_data.csv', index=False)
